# %% [markdown]
# # Tesla Stock Prediction Using LSTM

# %% [markdown]
# # Importing Libraries

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Reading The Data

# %%
data_dir = '/kaggle/input/tesla-stock-data-updated-till-28jun2021/TSLA.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2956 entries, 2010-06-29 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2956 non-null   float64
#  1   High       2956 non-null   float64
#  2   Low        2956 non-null   float64
#  3   Close      2956 non-null   float64
#  4   Adj Close  2956 non-null   float64
#  5   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 161.7 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2956.000000  2956.000000  2956.000000  2956.000000  2956.000000
# mean    138.691296   141.771603   135.425953   138.762183   138.762183
# std     250.044839   255.863239   243.774157   250.123115   250.123115
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      19.627000    20.402000    19.127500    19.615000    19.615000
# 50%      46.656999    47.487001    45.820002    46.545000    46.545000
# 75%      68.057001    69.357500    66.911501    68.103998    68.103998
# max    1234.410034  1243.489990  1217.000000  1229.910034  1229.910034
#
#              Volume
# count  2.956000e+03
# mean   3.131449e+07
# std    2.798383e+07
# min    5.925000e+05
# 25%    1.310288e+07
# 50%    2.488680e+07
# 75%    3.973875e+07
# max    3.046940e+08

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
# use pct_change to find the percent change for each day
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=50)
plt.ylabel('Daily Return')
plt.title(f'Tesla Dialy Return')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (2956, 1)

# %%
#Normalize the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
#splitting the data
# 75% to Train , 25% to Test
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 2217 Test Size : 739

# %%
train_data.shape, test_data.shape
# Out:
# ((2217, 1), (799, 1))

# %%
#create the train set
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((2157, 60, 1), (2157,))

# %% [markdown]
# # LSTM model

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60, 50)            10400
#
#  lstm_3 (LSTM)               (None, 64)                29440
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model training
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 68/68 [==============================] - 8s 62ms/step - loss: 1.0878e-04 - mean_absolute_error: 0.0068
# Epoch 2/100
# 68/68 [==============================] - 4s 61ms/step - loss: 5.0886e-06 - mean_absolute_error: 0.0016
# Epoch 3/100
# 68/68 [==============================] - 4s 61ms/step - loss: 5.4485e-06 - mean_absolute_error: 0.0017
# Epoch 4/100
# 68/68 [==============================] - 4s 61ms/step - loss: 5.4995e-06 - mean_absolute_error: 0.0018
# Epoch 5/100
# 68/68 [==============================] - 4s 62ms/step - loss: 5.0046e-06 - mean_absolute_error: 0.0016
# Epoch 6/100
# 68/68 [==============================] - 4s 61ms/step - loss: 4.3852e-06 - mean_absolute_error: 0.0015
# Epoch 7/100
# 68/68 [==============================] - 4s 63ms/step - loss: 4.3106e-06 - mean_absolute_error: 0.0015
# Epoch 8/100
# 68/68 [==============================] - 4s 65ms/step - loss: 6.0031e-06 - mean_absolute_error: 0.0019
# Epoch 9/100
# 68/68 [==============================] - 4s 61ms/step - loss: 4.5079e-06 - mean_absolute_error: 0.0016
# Epoch 10/100
# 68/68 [==============================] - 4s 62ms/step - loss: 4.9684e-06 - mean_absolute_error: 0.0017
# Epoch 11/100
# 68/68 [==============================] - 4s 63ms/step - loss: 4.2611e-06 - mean_absolute_error: 0.0015
# Epoch 12/100
# 68/68 [==============================] - 4s 61ms/step - loss: 4.7400e-06 - mean_absolute_error: 0.0017
# Epoch 13/100
# 68/68 [==============================] - 4s 63ms/step - loss: 3.8987e-06 - mean_absolute_error: 0.0014
# Epoch 14/100
# 68/68 [==============================] - 4s 66ms/step - loss: 4.7753e-06 - mean_absolute_error: 0.0017
# Epoch 15/100
# 68/68 [==============================] - 4s 62ms/step - loss: 4.0131e-06 - mean_absolute_error: 0.0015
# Epoch 16/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.3321e-06 - mean_absolute_error: 0.0013
# Epoch 17/100
# 68/68 [==============================] - 4s 62ms/step - loss: 3.3239e-06 - mean_absolute_error: 0.0013
# Epoch 18/100
# 68/68 [==============================] - 4s 62ms/step - loss: 4.2189e-06 - mean_absolute_error: 0.0016
# Epoch 19/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.0800e-06 - mean_absolute_error: 0.0013
# Epoch 20/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.3178e-06 - mean_absolute_error: 0.0013
# Epoch 21/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.3247e-06 - mean_absolute_error: 0.0014
# Epoch 22/100
# 68/68 [==============================] - 4s 64ms/step - loss: 3.2582e-06 - mean_absolute_error: 0.0013
# Epoch 23/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.0559e-06 - mean_absolute_error: 0.0013
# Epoch 24/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.8700e-06 - mean_absolute_error: 0.0013
# Epoch 25/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.1288e-06 - mean_absolute_error: 0.0013
# Epoch 26/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.4803e-06 - mean_absolute_error: 0.0011
# Epoch 27/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.6557e-06 - mean_absolute_error: 0.0012
# Epoch 28/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.7485e-06 - mean_absolute_error: 0.0013
# Epoch 29/100
# 68/68 [==============================] - 4s 63ms/step - loss: 3.0867e-06 - mean_absolute_error: 0.0013
# Epoch 30/100
# 68/68 [==============================] - 4s 63ms/step - loss: 2.9841e-06 - mean_absolute_error: 0.0013
# Epoch 31/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.9902e-06 - mean_absolute_error: 0.0013
# Epoch 32/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.3507e-06 - mean_absolute_error: 0.0011
# Epoch 33/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.1713e-06 - mean_absolute_error: 0.0014
# Epoch 34/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.4068e-06 - mean_absolute_error: 0.0012
# Epoch 35/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.1464e-06 - mean_absolute_error: 0.0011
# Epoch 36/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.4807e-06 - mean_absolute_error: 0.0012
# Epoch 37/100
# 68/68 [==============================] - 4s 64ms/step - loss: 2.6366e-06 - mean_absolute_error: 0.0012
# Epoch 38/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.3502e-06 - mean_absolute_error: 0.0011
# Epoch 39/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.1308e-06 - mean_absolute_error: 0.0011
# Epoch 40/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.3085e-06 - mean_absolute_error: 0.0012
# Epoch 41/100
# 68/68 [==============================] - 4s 62ms/step - loss: 1.9723e-06 - mean_absolute_error: 0.0010
# Epoch 42/100
# 68/68 [==============================] - 4s 63ms/step - loss: 3.8911e-06 - mean_absolute_error: 0.0015
# Epoch 43/100
# 68/68 [==============================] - 4s 62ms/step - loss: 1.9266e-06 - mean_absolute_error: 0.0010
# Epoch 44/100
# 68/68 [==============================] - 4s 64ms/step - loss: 2.5854e-06 - mean_absolute_error: 0.0012
# Epoch 45/100
# 68/68 [==============================] - 4s 65ms/step - loss: 2.3726e-06 - mean_absolute_error: 0.0012
# Epoch 46/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.1250e-06 - mean_absolute_error: 0.0011
# Epoch 47/100
# 68/68 [==============================] - 4s 63ms/step - loss: 2.2103e-06 - mean_absolute_error: 0.0011
# Epoch 48/100
# 68/68 [==============================] - 4s 62ms/step - loss: 1.6969e-06 - mean_absolute_error: 9.2747e-04
# Epoch 49/100
# 68/68 [==============================] - 4s 63ms/step - loss: 1.7906e-06 - mean_absolute_error: 9.5848e-04
# Epoch 50/100
# 68/68 [==============================] - 4s 61ms/step - loss: 1.9742e-06 - mean_absolute_error: 0.0010
# Epoch 51/100
# 68/68 [==============================] - 4s 62ms/step - loss: 2.7551e-06 - mean_absolute_error: 0.0013
# Epoch 52/100
# 68/68 [==============================] - 4s 63ms/step - loss: 2.0701e-06 - mean_absolute_error: 0.0011
# Epoch 53/100
# 68/68 [==============================] - 4s 61ms/step - loss: 3.5938e-06 - mean_absolute_error: 0.0015
# Epoch 54/100
# 68/68 [==============================] - 4s 62ms/step - loss: 1.6468e-06 - mean_absolute_error: 9.1383e-04
# Epoch 55/100
# 68/68 [==============================] - 4s 60ms/step - loss: 1.6626e-06 - mean_absolute_error: 9.2543e-04
# Epoch 56/100
# 68/68 [==============================] - 4s 61ms/step - loss: 1.5352e-06 - mean_absolute_error: 8.9709e-04
# Epoch 57/100
# 68/68 [==============================] - 4s 61ms/step - loss: 2.2243e-06 - mean_absolute_error: 0.0011
# Epoch 58/100
# 68/68 [==============================] - 4s 61ms/step - loss: 1.7417e-06 - mean_absolute_error: 9.7301e-04
# Epoch 59/100
# 68/68 [==============================] - 4s 61ms/step - loss: 1.8543e-06 - mean_absolute_error: 0.0010
# Epoch 60/100
# 68/68 [==============================] - 4s 63ms/step - loss: 1.7611e-06 - mean_absolute_error: 9.8732e-04
# Epoch 61/100
# 68/68 [==============================] - 4s 61ms/step - loss: 1.6628e-06 - mean_absolute_error: 9.5086e-04
# Epoch 62/100
# 68/68 [==============================] - 4s 59ms/step - loss: 1.7697e-06 - mean_absolute_error: 9.8651e-04
# Epoch 63/100
# 68/68 [==============================] - 4s 60ms/step - loss: 1.7362e-06 - mean_absolute_error: 9.6471e-04
# Epoch 64/100
# 68/68 [==============================] - 4s 60ms/step - loss: 1.7807e-06 - mean_absolute_error: 9.8212e-04
# Epoch 65/100
# 68/68 [==============================] - 4s 59ms/step - loss: 1.5819e-06 - mean_absolute_error: 8.9925e-04
# Epoch 66/100
# 68/68 [==============================] - 4s 60ms/step - loss: 1.8835e-06 - mean_absolute_error: 0.0010

# %%
#Evaluation
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Prediction

# %%
# creating test set
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((739, 60, 1), (739,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 24/24 [==============================] - 1s 21ms/step
# (739, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 21.69

# %%
#visializing prediciton with the data


train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %% [markdown]
# # Predict Next 30 Days

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157]
# 1/1 [==============================] - 0s 28ms/step
# [0.7597157, 0.7418805]
# 1/1 [==============================] - 0s 32ms/step
# [0.7597157, 0.7418805, 0.71350133]
# 1/1 [==============================] - 0s 37ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684]
# 1/1 [==============================] - 0s 35ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219]
# 1/1 [==============================] - 0s 35ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747]
# 1/1 [==============================] - 0s 35ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554]
# 1/1 [==============================] - 0s 37ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994]
# 1/1 [==============================] - 0s 35ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038]
# 1/1 [==============================] - 0s 35ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348]
# 1/1 [==============================] - 0s 37ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887]
# 1/1 [==============================] - 0s 32ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164]
# 1/1 [==============================] - 0s 32ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329]
# 1/1 [==============================] - 0s 32ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165]
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592]
# 1/1 [==============================] - 0s 34ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643]
# 1/1 [==============================] - 0s 34ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293]
# 1/1 [==============================] - 0s 36ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258]
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926]
# 1/1 [==============================] - 0s 32ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963, 0.37274662]
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963, 0.37274662, 0.36726043]
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963, 0.37274662, 0.36726043, 0.36195362]
# 1/1 [==============================] - 0s 31ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963, 0.37274662, 0.36726043, 0.36195362, 0.35683852]
# 1/1 [==============================] - 0s 33ms/step
# [0.7597157, 0.7418805, 0.71350133, 0.68165684, 0.6490219, 0.61720747, 0.5873174, 0.5600554, 0.5357803, 0.51456994, 0.49628922, 0.48066038, 0.46732348, 0.4558877, 0.44596887, 0.4372164, 0.429329, 0.42206165, 0.41522592, 0.40868643, 0.40235293, 0.39617258, 0.39012063, 0.3841926, 0.3783963, 0.37274662, 0.36726043, 0.36195362, 0.35683852, 0.3519235]

# %%
time
# Out:
# [Timestamp('2022-03-24 00:00:00'),
#  Timestamp('2022-03-25 00:00:00'),
#  Timestamp('2022-03-26 00:00:00'),
#  Timestamp('2022-03-27 00:00:00'),
#  Timestamp('2022-03-28 00:00:00'),
#  Timestamp('2022-03-29 00:00:00'),
#  Timestamp('2022-03-30 00:00:00'),
#  Timestamp('2022-03-31 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-04-02 00:00:00'),
#  Timestamp('2022-04-03 00:00:00'),
#  Timestamp('2022-04-04 00:00:00'),
#  Timestamp('2022-04-05 00:00:00'),
#  Timestamp('2022-04-06 00:00:00'),
#  Timestamp('2022-04-07 00:00:00'),
#  Timestamp('2022-04-08 00:00:00'),
#  Timestamp('2022-04-09 00:00:00'),
#  Timestamp('2022-04-10 00:00:00'),
#  Timestamp('2022-04-11 00:00:00'),
#  Timestamp('2022-04-12 00:00:00'),
#  Timestamp('2022-04-13 00:00:00'),
#  Timestamp('2022-04-14 00:00:00'),
#  Timestamp('2022-04-15 00:00:00'),
#  Timestamp('2022-04-16 00:00:00'),
#  Timestamp('2022-04-17 00:00:00'),
#  Timestamp('2022-04-18 00:00:00'),
#  Timestamp('2022-04-19 00:00:00'),
#  Timestamp('2022-04-20 00:00:00'),
#  Timestamp('2022-04-21 00:00:00'),
#  Timestamp('2022-04-22 00:00:00')]

# %% [markdown]
# # Predicte dataframe

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = forcasted_output.reshape(-1, 1) 
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %% [markdown]
# # predicting price

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2022-03-24  935.141235
# 1  2022-03-25  913.261902
# 2  2022-03-26  878.447815
# 3  2022-03-27  839.382568
# 4  2022-03-28  799.347717
# 5  2022-03-29  760.319336
# 6  2022-03-30  723.651672
# 7  2022-03-31  690.208008
# 8  2022-04-01  660.428528
# 9  2022-04-02  634.408691
# 10 2022-04-03  611.982788
# 11 2022-04-04  592.810120
# 12 2022-04-05  576.449097
# 13 2022-04-06  562.420227
# 14 2022-04-07  550.252319
# 15 2022-04-08  539.515198
# 16 2022-04-09  529.839355
# 17 2022-04-10  520.924133
# 18 2022-04-11  512.538391
# 19 2022-04-12  504.516083
# 20 2022-04-13  496.746460
# 21 2022-04-14  489.164734
# 22 2022-04-15  481.740479
# 23 2022-04-16  474.468262
# 24 2022-04-17  467.357666
# 25 2022-04-18  460.426910
# 26 2022-04-19  453.696716
# 27 2022-04-20  447.186615
# 28 2022-04-21  440.911652
# 29 2022-04-22  434.882141

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close' ,fontsize=18)
plt.plot(df['Close'])
plt.plot(df_result.set_index('Date')[['Forecasted']])
